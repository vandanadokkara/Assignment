# %%
import matplotlib.pyplot as plt
import numpy as np
#x-plot:
x=np.array([0,1,2,3])
y=np.array([9,4,6,8])
plt.subplot(1,2,1)
plt.plot(x,y)
#yplot:
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#x-plot:
x=np.array([0,1,2,3])
y=np.array([9,4,6,8])
plt.subplot(2,2,1)
plt.plot(x,y)
#yplot:
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,2,2)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#x-plot:
x=np.array([0,1,2,3])
y=np.array([9,4,6,8])
plt.subplot(3,2,1)
plt.plot(x,y)
#yplot:
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(3,2,2)
plt.plot(x,y)
import matplotlib.pyplot as plt
import numpy as np
#x-plot:
x=np.array([0,1,2,3])
y=np.array([9,4,6,8])
plt.subplot(3,2,3)
plt.plot(x,y)
#yplot:
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(3,2,4)
plt.plot(x,y)
import matplotlib.pyplot as plt
import numpy as np
#x-plot:
x=np.array([0,1,2,3])
y=np.array([9,4,6,8])
plt.subplot(3,2,4)
plt.plot(x,y)
#yplot:
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(3,2,5)
plt.plot(x,y)
import matplotlib.pyplot as plt
import numpy as np
#x-plot:
x=np.array([0,1,2,3])
y=np.array([9,4,6,8])
plt.subplot(3,2,6)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,3,3,1,1,1,2,3,1,3])
y=np.array([1,1,3,3,1,3,2,1,1,3])
plt.subplot(1,1,1)
plt.plot(x,y,marker="o",mec="red",color="hotpink")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,1,3,3,1,2,3,2.5,2.5,2,2,1.5,1.5,1.5,1.5,1,1,1,1.25,2.75,2.34,2.34,1.65])
y=np.array([4,1,1,4,4,7,4,4,1,1,4,4,1,1,1,1,4,4,4.7,4.7,6,6,6])
plt.subplot(1,1,1)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([2,3,4,4,4,2,2,4])
y=np.array([1,1,1,4,4,4,6,6])
plt.subplot(1,1,1)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as py
x=np.array([1,3,2,2,2,1.75])
y=np.array([1,1,1,4,4,3.3])
plt.subplot(1,1,1)
plt.plot(x,y)
plt.show()
