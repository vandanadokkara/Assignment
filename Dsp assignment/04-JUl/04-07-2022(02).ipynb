# %%
import matplotlib.pyplot as plt
import numpy as np
data=[10,20,30,40,50]
plt.boxplot(data)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
data1=[10,20,30,40,50]
data2=[55,60,65,70,75]
data=[data1,data2]
plt.boxplot(data)
plt.show()

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(10,5)*10,columns=['A','B','c','D','e'])
df.plot.box()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(10,5)*10,columns=['A','B','c','D','e'])
df.plot(kind='box')
#kind=pie
# Out:
# <AxesSubplot:>
