# %%
import matplotlib.pyplot as plt
import pandas as pd
x=[1,2,3,4,5]
y=[10,20,30,40,50]
color=['red','green','orange','hotpink','black']
size=[50,60,70,80,90]
plt.scatter(x,y,c=color,s=size,linewidth=4,edgecolor="olive",marker="*")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
x=[1,2,3,4,5]
y=[10,20,30,40,50]
color=['red','green','orange','hotpink','black']
size=[50,60,70,80,90]
plt.scatter(x,y,c=color,s=size,marker="^",linewidth=6,edgecolor='blue')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=[21,34,23,12,38,87,45,34,3,24,56,54,34,33,65,45,67,77]
y=[13,45,67,98,5,34,65,87,4,35,87,35,78,24,78,56,78,43]
color='red'
plt.scatter(x,y,c=color)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.random.normal(5,1,1000)
y=np.random.normal(10,2,1000)
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=[2,3,4,5,6,7,8]
y=[10,20,32,45,65,54,34]
color=['red','green','orange','hotpink','yellow','black','brown']
size=[45,50,55,60,65,70,75]
plt.scatter(x,y,c=color,s=size)
plt.show()
