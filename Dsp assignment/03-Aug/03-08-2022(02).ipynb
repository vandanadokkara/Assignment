# %%
import pandas as pd
data=pd.read_csv("bollywood.csv")
print(data)
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1    18-Apr-14                     2 States          LW    Romance
# 1       2     4-Jan-13                 Table No. 21           N  Thriller
# 2       3    18-Jul-14           Amit Sahni Ki List           N     Comedy
# 3       4     4-Jan-13             Rajdhani Express           N     Drama
# 4       5     4-Jul-14                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N     Comedy
# 145   146    13-Mar-15                         NH10           N   Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148    20-Mar-15                     Hunterrr           N     Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS     Action
#
# ...

# %%
#How many records are present in the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SlNo                 149 non-null    int64
#  1   Release Date         149 non-null    object
#  2   MovieName            149 non-null    object
#  3   ReleaseTime          149 non-null    object
#  4   Genre                149 non-null    object
#  5   Budget               149 non-null    int64
#  6   BoxOfficeCollection  149 non-null    float64
#  7   YoutubeViews         149 non-null    int64
#  8   YoutubeLikes         149 non-null    int64
#  9   YoutubeDislikes      149 non-null    int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 11.8+ KB

# %%
data.head(100)
# Out:
#     SlNo Release Date           MovieName ReleaseTime      Genre  Budget  \
# 0      1    18-Apr-14            2 States          LW    Romance      36
# 1      2     4-Jan-13        Table No. 21           N  Thriller       10
# 2      3    18-Jul-14  Amit Sahni Ki List           N     Comedy      10
# 3      4     4-Jan-13    Rajdhani Express           N     Drama        7
# 4      5     4-Jul-14        Bobby Jasoos           N     Comedy      18
# ..   ...          ...                 ...         ...        ...     ...
# 95    96    28-Jun-13         Ghanchakkar           N     Comedy      30
# 96    97     2-Oct-13            Besharam          LW     Comedy      85
# 97    98     5-Jul-13             Lootera           N    Romance      27
# 98    99    18-Jul-14            Pizza 3D           N   Thriller      10
# 99   100    16-May-14           The Xpose          HS   Thriller      16
#
#     BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# ...

# %%
data.tail(10)
# Out:
#      SlNo Release Date                    MovieName ReleaseTime     Genre  \
# 139   140    30-Jan-15                   Hawaizaada           N    Drama
# 140   141    30-Jan-15                  Khamoshiyan           N  Thriller
# 141   142     6-Feb-15                    Shamitabh           N    Drama
# 142   143    13-Feb-15                          Roy          FS   Romance
# 143   144    20-Feb-15                     Badlapur          FS    Action
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N    Comedy
# 145   146    13-Mar-15                         NH10           N  Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N    Comedy
# 147   148    20-Mar-15                     Hunterrr           N    Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS    Action
#
#      Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 139      25                30.25       2368404          8619              539
# ...

# %%
data.describe()
# Out:
#              SlNo      Budget  BoxOfficeCollection  YoutubeViews  \
# count  149.000000  149.000000           149.000000  1.490000e+02
# mean    75.000000   29.442953            55.667248  3.337920e+06
# std     43.156691   28.237981            94.494531  3.504407e+06
# min      1.000000    2.000000             0.010000  4.354000e+03
# 25%     38.000000   11.000000             8.780000  1.076591e+06
# 50%     75.000000   21.000000            28.000000  2.375050e+06
# 75%    112.000000   35.000000            57.450000  4.550051e+06
# max    149.000000  150.000000           735.000000  2.317107e+07
#
#         YoutubeLikes  YoutubeDislikes
# count     149.000000       149.000000
# mean     7877.536913      1207.818792
# std     12748.047191      1852.692938
# min         1.000000         1.000000
# 25%      1377.000000       189.000000
# 50%      4111.000000       614.000000
# 75%      9100.000000      1419.000000
# max    101275.000000     11888.000000

# %%
a=data.groupby(["Genre","MovieName"]).groups
print(a)
# Out:
# {(' Drama ', 'ABCD _ Any Body Can Dance'): [27], (' Drama ', 'Aurangzeb'): [76], (' Drama ', 'B.A. Pass'): [104], (' Drama ', 'Bhaag Milkha Bhaag'): [101], (' Drama ', 'Bombay Talkies'): [70], (' Drama ', 'Boss'): [127], (' Drama ', 'Children Of War'): [133], (' Drama ', 'Citylights'): [5], (' Drama ', 'Gangoobai'): [9], (' Drama ', 'Haider'): [23], (' Drama ', 'Happy New Year'): [26], (' Drama ', 'Hawaa Hawaai'): [29], (' Drama ', 'Hawaizaada'): [139], (' Drama ', 'Highway'): [34], (' Drama ', 'Kaanchi'): [102], (' Drama ', 'Kai Po Che!'): [33], (' Drama ', 'Kya Dilli Kya Lahore'): [49], (' Drama ', 'Manjunath'): [55], (' Drama ', 'Mardaani'): [56], (' Drama ', 'Mary Kom'): [58], (' Drama ', 'Miss Lovely'): [63], (' Drama ', 'PK'): [89], (' Drama ', 'Phata Poster Nikla Hero'): [134], (' Drama ', 'Queen'): [69], (' Drama ', 'Rajdhani Express'): [3], (' Drama ', 'Revolver Rani'): [74], (' Drama ', 'Saheb, Biwi Aur Gangster Returns'): [40], (' Drama ', 'Satyagraha'): [118], (' Drama ',
# ...

# %%
print(data.max())
# Out:
# SlNo                               149
# Release Date                  9-May-14
# MovieName              Zilla Ghaziabad
# ReleaseTime                          N
# Genre                        Thriller
# Budget                             150
# BoxOfficeCollection              735.0
# YoutubeViews                  23171067
# YoutubeLikes                    101275
# YoutubeDislikes                  11888
# dtype: object

# %%
print(data.min())
# Out:
# SlNo                          1
# Release Date           1-Feb-13
# MovieName              2 States
# ReleaseTime                  FS
# Genre                    Drama
# Budget                        2
# BoxOfficeCollection        0.01
# YoutubeViews               4354
# YoutubeLikes                  1
# YoutubeDislikes               1
# dtype: object

# %%
a=data["Genre"].value_counts()
print(a)
# Out:
# Comedy       36
#  Drama       35
# Thriller     26
# Romance      25
# Action       21
# Thriller      3
# Action        3
# Name: Genre, dtype: int64

# %%
data["Genre"].max()
# Out:
# 'Thriller '

# %%
data.head()
# Out:
#    SlNo Release Date           MovieName ReleaseTime      Genre  Budget  \
# 0     1    18-Apr-14            2 States          LW    Romance      36
# 1     2     4-Jan-13        Table No. 21           N  Thriller       10
# 2     3    18-Jul-14  Amit Sahni Ki List           N     Comedy      10
# 3     4     4-Jan-13    Rajdhani Express           N     Drama        7
# 4     5     4-Jul-14        Bobby Jasoos           N     Comedy      18
#
#    BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 0               104.00       8576361         26622             2527
# 1                12.00       1087320          1129              137
# 2                 4.00        572336           586               54
# 3                 0.35         42626            86               19
# 4                10.80       3113427          4512             1224

# %%
data.tail()
# Out:
#      SlNo Release Date                    MovieName ReleaseTime     Genre  \
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N    Comedy
# 145   146    13-Mar-15                         NH10           N  Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N    Comedy
# 147   148    20-Mar-15                     Hunterrr           N    Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS    Action
#
#      Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 144      15                30.00       3250917          8185              615
# 145      13                32.10       5592977         15464             1513
# 146      32                12.00       2316047          4289              807
# 147       5                11.89       4674795          3706              762
# 148     150               120.00       4740727         13466             2649

# %%
data.columns
# Out:
# Index(['SlNo', 'Release Date', 'MovieName', 'ReleaseTime', 'Genre', 'Budget',
#        'BoxOfficeCollection', 'YoutubeViews', 'YoutubeLikes',
#        'YoutubeDislikes'],
#       dtype='object')

# %%
data.head(5).transpose()
# Out:
#                              0             1                   2  \
# SlNo                         1             2                   3
# Release Date         18-Apr-14      4-Jan-13           18-Jul-14
# MovieName             2 States  Table No. 21  Amit Sahni Ki List
# ReleaseTime                 LW             N                   N
# Genre                  Romance     Thriller               Comedy
# Budget                      36            10                  10
# BoxOfficeCollection      104.0          12.0                 4.0
# YoutubeViews           8576361       1087320              572336
# YoutubeLikes             26622          1129                 586
# YoutubeDislikes           2527           137                  54
#
#                                     3             4
# SlNo                                4             5
# Release Date                 4-Jan-13      4-Jul-14
# MovieName            Rajdhani Express  Bobby Jasoos
# ...

# %%
data.shape
# Out:
# (149, 10)

# %%
a=data[0:10]
a
# Out:
#    SlNo Release Date                   MovieName ReleaseTime      Genre  \
# 0     1    18-Apr-14                    2 States          LW    Romance
# 1     2     4-Jan-13                Table No. 21           N  Thriller
# 2     3    18-Jul-14          Amit Sahni Ki List           N     Comedy
# 3     4     4-Jan-13            Rajdhani Express           N     Drama
# 4     5     4-Jul-14                Bobby Jasoos           N     Comedy
# 5     6    30-May-14                  Citylights          HS     Drama
# 6     7    19-Sep-14               Daawat-E-Ishq           N     Comedy
# 7     8    11-Jan-13  Matru Ki Bijlee Ka Mandola           N     Comedy
# 8     9    10-Jan-14                Dedh Ishqiya          LW     Comedy
# 9    10    11-Jan-13                   Gangoobai           N     Drama
#
#    Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 0      36               104.00       8576361         26622             2527
# ...

# %%
b=data[20:41]
b
# Out:
#     SlNo Release Date                         MovieName ReleaseTime  \
# 20    21     1-Feb-13                             David           N
# 21    22     7-Mar-14                       Gulaab Gang           N
# 22    23    14-Feb-14                            Gunday           N
# 23    24     2-Oct-14                            Haider          FS
# 24    25    21-Nov-14                      Happy Ending           N
# 25    26     8-Feb-13                        Special 26           N
# 26    27    24-Oct-14                    Happy New Year          LW
# 27    28     8-Feb-13         ABCD _ Any Body Can Dance           N
# 28    29    18-Jul-14                      Hate Story 2           N
# 29    30     9-May-14                      Hawaa Hawaai          HS
# 30    31     7-Feb-14                         Heartless           N
# 31    32    15-Feb-13                          Murder 3          FS
# 32    33    23-May-14                         Heropanti          HS
# ...

# %%
data[["MovieName","Genre"]][0:5]
# Out:
#             MovieName      Genre
# 0            2 States    Romance
# 1        Table No. 21  Thriller
# 2  Amit Sahni Ki List     Comedy
# 3    Rajdhani Express     Drama
# 4        Bobby Jasoos     Comedy

# %%
data["Genre"].value_counts()
# Out:
# Comedy       36
#  Drama       35
# Thriller     26
# Romance      25
# Action       21
# Thriller      3
# Action        3
# Name: Genre, dtype: int64

# %%
data["Genre"].sort_values()
# Out:
# 74        Drama
# 25        Drama
# 26        Drama
# 27        Drama
# 29        Drama
#          ...
# 31      Thriller
# 116     Thriller
# 16     Thriller
# 1      Thriller
# 20     Thriller
# Name: Genre, Length: 149, dtype: object

# %%
data["Genre"].max()
# Out:
# 'Thriller '

# %%
#decending order
data["Genre"].sort_values(ascending=False)
# Out:
# 20     Thriller
# 1      Thriller
# 16     Thriller
# 30      Thriller
# 44      Thriller
#          ...
# 120       Drama
# 49        Drama
# 102       Drama
# 40        Drama
# 74        Drama
# Name: Genre, Length: 149, dtype: object
