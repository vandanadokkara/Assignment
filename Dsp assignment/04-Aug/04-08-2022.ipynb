# %%
import pandas as pd
df=pd.read_csv("IPL.csv")
df
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
# ...

# %%
len(df)
# Out:
# 130

# %%
df.head()
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1         657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2        1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 3         241     84.56  ...   76.32       0    1125    49   22.96   6.23
# 4          79     45.93  ...  120.71      28       0     0    0.00   0.00
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
df.sample()
# Out:
#     Sl.NO.  PLAYER NAME  AGE COUNTRY TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 22      23  Fleming, SP    3      NZ  CSK      Batsman    7172       0
#
#     ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL  ECON  \
# 22        8037     71.49  ...  118.78       3       0     0     0.0   0.0
#
#     SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# 22    0.0          2008      350000      350000
#
# [1 rows x 26 columns]

# %%
df.sample()
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL  ECON  \
# 127        8051     87.58  ...  131.88      67     569    23   24.74  7.02
#
#      SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# 127  21.13          2011      400000     1800000
#
# [1 rows x 26 columns]

# %%
df.tail(20)
# Out:
#      Sl.NO.       PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  \
# 110     111      Taylor, LRPL    2      NZ   RCB+      Batsman    2742
# 111     112     Tendulkar, SR    3     IND     MI      Batsman   15470
# 112     113        Tiwary, MK    2     IND    DD+      Batsman       0
# 113     114        Tiwary, SS    1     IND    MI+      Batsman       0
# 114     115          Tyagi, S    1     IND    CSK       Bowler       0
# 115     116          Umar Gul    2     PAK    KKR       Bowler     541
# 116     117       Uthappa, RV    2     IND   RCB+      Batsman       0
# 117     118       Vaas, WPUJC    3      SL     DC       Bowler    3089
# 118     119     Van der Merwe    2      SA   RCB+   Allrounder       0
# 119     120  Venugopal Rao, Y    2     IND    DC+      Batsman       0
# 120     121       Vettori, DL    2      NZ    DD+   Allrounder    4486
# 121     122    Vinay Kumar, R    2     IND   RCB+       Bowler      11
# ...

# %%
a=df.head(30)
a
# Out:
#     Sl.NO.      PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0        1      Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1        2     Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2        3      Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3        4        Ashwin, R    1     IND   CSK       Bowler     284      31
# 4        5     Badrinath, S    2     IND   CSK      Batsman      63       0
# 5        6       Bailey, GJ    2     AUS   CSK      Batsman       0       0
# 6        7        Balaji, L    2     IND  CSK+       Bowler      51      27
# 7        8    Bollinger, DE    2     AUS   CSK       Bowler      54      50
# 8        9         Botha, J    2      SA    RR   Allrounder      83      17
# 9       10      Boucher, MV    2      SA  RCB+    W. Keeper    5515       1
# 10      11        Bravo, DJ    2      WI   MI+   Allrounder    2200      86
# ...

# %%
a.tail(10)
# Out:
#     Sl.NO.    PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 20      21    Edwards, FH    2      WI    DC       Bowler     380     157
# 21      22  Fernando, CRD    2      SL    MI       Bowler     249      97
# 22      23    Fleming, SP    3      NZ   CSK      Batsman    7172       0
# 23      24    Flintoff, A    2     ENG   CSK   Allrounder    3845     226
# 24      25     Gambhir, G    2     IND   DD+      Batsman    3712       0
# 25      26    Ganguly, SC    3     IND  KKR+      Batsman    7212      32
# 26      27      Gayle, CH    2      WI  KKR+   Allrounder    6373      72
# 27      28      Gibbs, HH    3      SA    DC      Batsman    6167       0
# 28      29  Gilchrist, AC    3     AUS   DC+    W. Keeper    5570       0
# 29      30       Gony, MS    2     IND  CSK+       Bowler       0       0
#
#     ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL  ECON  \
# 20          73     45.62  ...   80.00       0     154     5   30.80  6.60
# ...

# %%
#Finding MetaData
df.columns
# Out:
# Index(['Sl.NO.', 'PLAYER NAME', 'AGE', 'COUNTRY', 'TEAM', 'PLAYING ROLE',
#        'T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
#        'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C',
#        'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE',
#        'SOLD PRICE'],
#       dtype='object')

# %%
df.head(5).transpose()
# Out:
#                          0             1            2          3             4
# Sl.NO.                   1             2            3          4             5
# PLAYER NAME    Abdulla, YA  Abdur Razzak  Agarkar, AB  Ashwin, R  Badrinath, S
# AGE                      2             2            2          1             2
# COUNTRY                 SA           BAN          IND        IND           IND
# TEAM                  KXIP           RCB          KKR        CSK           CSK
# PLAYING ROLE    Allrounder        Bowler       Bowler     Bowler       Batsman
# T-RUNS                   0           214          571        284            63
# T-WKTS                   0            18           58         31             0
# ODI-RUNS-S               0           657         1269        241            79
# ODI-SR-B               0.0         71.41        80.62      84.56         45.93
# ODI-WKTS                 0           185          288         51             0
# ...

# %%
df.shape
# Out:
# (130, 26)

# %%
#Summary of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.NO.         130 non-null    int64
#  1   PLAYER NAME    130 non-null    object
#  2   AGE            130 non-null    int64
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING ROLE   130 non-null    object
#  6   T-RUNS         130 non-null    int64
#  7   T-WKTS         130 non-null    int64
#  8   ODI-RUNS-S     130 non-null    int64
#  9   ODI-SR-B       130 non-null    float64
#  10  ODI-WKTS       130 non-null    int64
#  11  ODI-SR-BL      130 non-null    float64
#  12  CAPTAINCY EXP  130 non-null    int64
#  13  RUNS-S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
#  16  SR-B           130 non-null    float64
# ...

# %%
df[10:21]
# Out:
#     Sl.NO.      PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 10      11        Bravo, DJ    2      WI   MI+   Allrounder    2200      86
# 11      12   Chanderpaul, S    3      WI   RCB      Batsman    9918       9
# 12      13       Chawla, PP    1     IND  KXIP   Allrounder       5       3
# 13      14  de Villiers, AB    2      SA   DD+    W. Keeper    5457       2
# 14      15        Dhawan, S    2     IND   MI+      Batsman       0       0
# 15      16        Dhoni, MS    2     IND   CSK    W. Keeper    3509       0
# 16      17      Dilshan, TM    2      SL   DD+   Allrounder    4722      32
# 17      18        Dinda, AB    2     IND  KKR+       Bowler       0       0
# 18      19       Dravid, RS    3     IND  RCB+      Batsman   13288       1
# 19      20      Duminy, J-P    2      SA   MI+      Batsman     654      11
# 20      21      Edwards, FH    2      WI    DC       Bowler     380     157
#
# ...

# %%
df[-1:]
# Out:
#      Sl.NO. PLAYER NAME  AGE COUNTRY TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 129     130  Zoysa, DNT    2      SL   DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL  ECON  \
# 129         343     95.81  ...  122.22       0      99     2    49.5   9.0
#
#      SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# 129   33.0          2008      100000      110000
#
# [1 rows x 26 columns]

# %%
df[-10:]
# Out:
#      Sl.NO.     PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 120     121     Vettori, DL    2      NZ    DD+   Allrounder    4486     359
# 121     122  Vinay Kumar, R    2     IND   RCB+       Bowler      11       1
# 122     123       Warne, SK    3     AUS     RR       Bowler    3154     708
# 123     124      Warner, DA    1     AUS     DD      Batsman     483       2
# 124     125       White, CL    2     AUS   RCB+      Batsman     146       5
# 125     126       Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127     Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128    Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129     Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130      Zoysa, DNT    2      SL     DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# ...

# %%
df[-3:-1]
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL  ECON  \
# 127        8051     87.58  ...  131.88      67     569    23   24.74  7.02
# 128         790     73.55  ...   91.67       1    1783    65   27.43  7.75
#
#      SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# 127  21.13          2011      400000     1800000
# 128  21.26          2008      200000      450000
#
# [2 rows x 26 columns]

# %%
df[1:5:2]
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 1       2  Abdur Razzak    2     BAN  RCB       Bowler     214      18
# 3       4     Ashwin, R    1     IND  CSK       Bowler     284      31
#
#    ODI-RUNS-S  ODI-SR-B  ...   SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 1         657     71.41  ...   0.00       0      29     0    0.00  14.50
# 3         241     84.56  ...  76.32       0    1125    49   22.96   6.23
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# 1   0.00          2008       50000       50000
# 3  22.14          2011      100000      850000
#
# [2 rows x 26 columns]

# %%
#Selecting Columns names
df["TEAM"][0:10]
# Out:
# 0    KXIP
# 1     RCB
# 2     KKR
# 3     CSK
# 4     CSK
# 5     CSK
# 6    CSK+
# 7     CSK
# 8      RR
# 9    RCB+
# Name: TEAM, dtype: object

# %%
df[["TEAM","PLAYING ROLE"]][0:5]
# Out:
#    TEAM PLAYING ROLE
# 0  KXIP   Allrounder
# 1   RCB       Bowler
# 2   KKR       Bowler
# 3   CSK       Bowler
# 4   CSK      Batsman

# %%
#Selecting rows and columns
df.iloc[1:5,2:5]
# Out:
#    AGE COUNTRY TEAM
# 1    2     BAN  RCB
# 2    2     IND  KKR
# 3    1     IND  CSK
# 4    2     IND  CSK

# %%
k=df["COUNTRY"].value_counts()
print(k)
# Out:
# IND    53
# AUS    22
# SA     16
# SL     12
# PAK     9
# NZ      7
# WI      6
# ENG     3
# BAN     1
# ZIM     1
# Name: COUNTRY, dtype: int64

# %%
k[k==k.max()]
# Out:
# IND    53
# Name: COUNTRY, dtype: int64

# %%
df.COUNTRY.value_counts(normalize=True)*100
# Out:
# IND    40.769231
# AUS    16.923077
# SA     12.307692
# SL      9.230769
# PAK     6.923077
# NZ      5.384615
# WI      4.615385
# ENG     2.307692
# BAN     0.769231
# ZIM     0.769231
# Name: COUNTRY, dtype: float64

# %%
#CrossTable between two columns
pd.crosstab(df["AGE"],df["PLAYING ROLE"])
# Out:
# PLAYING ROLE  Allrounder  Batsman  Bowler  W. Keeper
# AGE
# 1                      4        5       7          0
# 2                     25       21      29         11
# 3                      6       13       8          1

# %%
df[["PLAYER NAME","SOLD PRICE"]].sort_values("SOLD PRICE")[0:5].reset_index()
# Out:
#    index    PLAYER NAME  SOLD PRICE
# 0     73     Noffke, AA       20000
# 1     46    Kamran Khan       24000
# 2      0    Abdulla, YA       50000
# 3      1   Abdur Razzak       50000
# 4    118  Van der Merwe       50000

# %%
df[["PLAYING ROLE","T-RUNS"]].sort_values("T-RUNS")
# Out:
#     PLAYING ROLE  T-RUNS
# 0     Allrounder       0
# 82    Allrounder       0
# 33    Allrounder       0
# 96    Allrounder       0
# 97       Batsman       0
# ..           ...     ...
# 42       Batsman   10440
# 44    Allrounder   12379
# 86       Batsman   13218
# 18       Batsman   13288
# 111      Batsman   15470
#
# [130 rows x 2 columns]

# %%
df[["PLAYING ROLE","T-RUNS"]].sort_values("T-RUNS")[0:10]
# Out:
#     PLAYING ROLE  T-RUNS
# 0     Allrounder       0
# 82    Allrounder       0
# 33    Allrounder       0
# 96    Allrounder       0
# 97       Batsman       0
# 34    Allrounder       0
# 78        Bowler       0
# 36    Allrounder       0
# 37    Allrounder       0
# 112      Batsman       0

# %%
df[["PLAYING ROLE","T-RUNS"]].sort_values("PLAYING ROLE")[0:10].reset_index()
# Out:
#    index PLAYING ROLE  T-RUNS
# 0      0   Allrounder       0
# 1     99   Allrounder    1606
# 2     26   Allrounder    6373
# 3     61   Allrounder     107
# 4    102   Allrounder     320
# 5     59   Allrounder    1219
# 6     58   Allrounder       0
# 7     56   Allrounder     556
# 8     33   Allrounder       0
# 9     34   Allrounder       0

# %%
df[["PLAYING ROLE","SOLD PRICE"]].sort_values("SOLD PRICE",ascending=True)[0:5].reset_index()
# Out:
#    index PLAYING ROLE  SOLD PRICE
# 0     73   Allrounder       20000
# 1     46       Bowler       24000
# 2      0   Allrounder       50000
# 3      1       Bowler       50000
# 4    118   Allrounder       50000

# %%
#NEW columns
df["PREMIUM"]=df["SOLD PRICE"]-df["BASE PRICE"]

# %%
df[["PLAYER NAME","SOLD PRICE","BASE PRICE","PREMIUM"]][0:5]
# Out:
#     PLAYER NAME  SOLD PRICE  BASE PRICE  PREMIUM
# 0   Abdulla, YA       50000       50000        0
# 1  Abdur Razzak       50000       50000        0
# 2   Agarkar, AB      350000      200000   150000
# 3     Ashwin, R      850000      100000   750000
# 4  Badrinath, S      800000      100000   700000

# %%
df[["PLAYER NAME","SOLD PRICE","BASE PRICE","PREMIUM"]].sort_values("PREMIUM")[0:5]
# Out:
#         PLAYER NAME  SOLD PRICE  BASE PRICE  PREMIUM
# 0       Abdulla, YA       50000       50000        0
# 40        Jaffer, W      150000      150000        0
# 45     Kamran Akmal      150000      150000        0
# 49       Katich, SM      200000      200000        0
# 58  Mascarenhas, AD      100000      100000        0

# %%
df.groupby('AGE')['SOLD PRICE'].mean()
# Out:
# AGE
# 1    720250.000000
# 2    484534.883721
# 3    520178.571429
# Name: SOLD PRICE, dtype: float64

# %%
df.groupby('PLAYER NAME')['SOLD PRICE'].mean()
# Out:
# PLAYER NAME
# Abdulla, YA          50000.0
# Abdur Razzak         50000.0
# Agarkar, AB         350000.0
# Ashwin, R           850000.0
# Badrinath, S        800000.0
#                      ...
# Younis Khan         225000.0
# Yuvraj Singh       1800000.0
# Zaheer Khan         450000.0
# Zoysa, DNT          110000.0
# de Villiers, AB     300000.0
# Name: SOLD PRICE, Length: 130, dtype: float64

# %%
df.groupby("AGE")["SOLD PRICE"].mean().reset_index()
# Out:
#    AGE     SOLD PRICE
# 0    1  720250.000000
# 1    2  484534.883721
# 2    3  520178.571429

# %%
df.groupby(["AGE","PLAYING ROLE"])["SOLD PRICE"].mean().reset_index()
# Out:
#     AGE PLAYING ROLE    SOLD PRICE
# 0     1   Allrounder  5.875000e+05
# 1     1      Batsman  1.110000e+06
# 2     1       Bowler  5.177143e+05
# 3     2   Allrounder  4.494000e+05
# 4     2      Batsman  6.547619e+05
# 5     2       Bowler  3.979310e+05
# 6     2    W. Keeper  4.677273e+05
# 7     3   Allrounder  7.666667e+05
# 8     3      Batsman  4.576923e+05
# 9     3       Bowler  4.143750e+05
# 10    3    W. Keeper  7.000000e+05
