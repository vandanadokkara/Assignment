# %%
import pandas as pd
a=[4,5,9]
s=pd.Series(a)
print(s)
print(s[0])
# Out:
# 0    4
# 1    5
# 2    9
# dtype: int64
# 4

# %%
import pandas as pd
a=[1,2,3]
x=pd.Series(a,index=["v","n","l"])
print(x)
# Out:
# v    1
# n    2
# l    3
# dtype: int64

# %%
import pandas as pd
a=pd.DataFrame({"abc":123,"cft":456},index=[9,8])
print(a)
# Out:
#    abc  cft
# 9  123  456
# 8  123  456

# %%
import pandas as pd
a=pd.read_csv("data.csv")
a
# Out:
#         Name  Age  marks
# 0    vandana   12     67
# 1     joshna   22     98
# 2      manoj   15     87
# 3     kamala   45     89
# 4    apparao   56     99
# ..       ...  ...    ...
# 185    babbu   13     42
# 186    sanju   43     59
# 187     uday   34     74
# 188    bunny   11     37
# 189    babbu   13     42
#
# [190 rows x 3 columns]

# %%
a.describe()
# Out:
#               Age       marks
# count  190.000000  190.000000
# mean    27.721053   70.152632
# std     13.924250   19.652615
# min     11.000000   37.000000
# 25%     15.000000   56.750000
# 50%     23.000000   69.000000
# 75%     40.750000   87.000000
# max     56.000000   99.000000

# %%
a.min()
# Out:
# Name     akky
# Age        11
# marks      37
# dtype: object

# %%
a.max()
# Out:
# Name     vandana
# Age           56
# marks         99
# dtype: object

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    190 non-null    object
#  1   Age     190 non-null    int64
#  2   marks   190 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 4.6+ KB

# %%
a.head()
# Out:
#       Name  Age  marks
# 0  vandana   12     67
# 1   joshna   22     98
# 2    manoj   15     87
# 3   kamala   45     89
# 4  apparao   56     99

# %%
a.head(100)
# Out:
#        Name  Age  marks
# 0   vandana   12     67
# 1    joshna   22     98
# 2     manoj   15     87
# 3    kamala   45     89
# 4   apparao   56     99
# ..      ...  ...    ...
# 95     akky   21     56
# 96    sanju   43     59
# 97     uday   34     74
# 98    bunny   11     37
# 99    babbu   13     42
#
# [100 rows x 3 columns]

# %%
a.tail()
# Out:
#       Name  Age  marks
# 185  babbu   13     42
# 186  sanju   43     59
# 187   uday   34     74
# 188  bunny   11     37
# 189  babbu   13     42

# %%
b=a.tail(100)
b
# Out:
#         Name  Age  marks
# 90     manoj   15     87
# 91    kamala   45     89
# 92   apparao   56     99
# 93     jeeva   34     78
# 94     neelu   23     69
# ..       ...  ...    ...
# 185    babbu   13     42
# 186    sanju   43     59
# 187     uday   34     74
# 188    bunny   11     37
# 189    babbu   13     42
#
# [100 rows x 3 columns]

# %%
print(b)
# Out:
#         Name  Age  marks
# 90     manoj   15     87
# 91    kamala   45     89
# 92   apparao   56     99
# 93     jeeva   34     78
# 94     neelu   23     69
# ..       ...  ...    ...
# 185    babbu   13     42
# 186    sanju   43     59
# 187     uday   34     74
# 188    bunny   11     37
# 189    babbu   13     42
#
# [100 rows x 3 columns]

# %%
a.head(20)
# Out:
#        Name  Age  marks
# 0   vandana   12     67
# 1    joshna   22     98
# 2     manoj   15     87
# 3    kamala   45     89
# 4   apparao   56     99
# 5     jeeva   34     78
# 6     neelu   23     69
# 7      akky   21     56
# 8     sanju   43     59
# 9      uday   34     74
# 10    bunny   11     37
# 11    babbu   13     42
# 12  vandana   19     67
# 13   joshna   22     98
# 14    manoj   15     87
# 15   kamala   45     89
# 16  apparao   56     99
# 17    jeeva   34     78
# 18    neelu   23     69
# 19     akky   21     56

# %%
a["Age"]
# Out:
# 0      12
# 1      22
# 2      15
# 3      45
# 4      56
#        ..
# 185    13
# 186    43
# 187    34
# 188    11
# 189    13
# Name: Age, Length: 190, dtype: int64

# %%
a["Age"].max()
# Out:
# 56

# %%
a["Age"].min()
# Out:
# 11

# %%
titanic.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 titanic.head(10)
#
# NameError: name 'titanic' is not defined

# %%
a["adress"]=0
print(a)
# Out:
#         Name  Age  marks  adress
# 0    vandana   12     67       0
# 1     joshna   22     98       0
# 2      manoj   15     87       0
# 3     kamala   45     89       0
# 4    apparao   56     99       0
# ..       ...  ...    ...     ...
# 185    babbu   13     42       0
# 186    sanju   43     59       0
# 187     uday   34     74       0
# 188    bunny   11     37       0
# 189    babbu   13     42       0
#
# [190 rows x 4 columns]

# %%
a.loc[0]
# Out:
# Name      vandana
# Age            12
# marks          67
# adress          0
# Name: 0, dtype: object

# %%
a.loc[189]
# Out:
# Name      babbu
# Age          13
# marks        42
# adress        0
# Name: 189, dtype: object

# %%
a.loc[0,"Name"]
# Out:
# 'vandana'

# %%
df=a[(a.Age>35)&(a.marks>60)]
df
# Out:
#         Name  Age  marks  adress
# 3     kamala   45     89       0
# 4    apparao   56     99       0
# 15    kamala   45     89       0
# 16   apparao   56     99       0
# 27    kamala   45     89       0
# 28   apparao   56     99       0
# 39    kamala   45     89       0
# 40   apparao   56     99       0
# 51    kamala   45     89       0
# 52   apparao   56     99       0
# 63    kamala   45     89       0
# 64   apparao   56     99       0
# 75    kamala   45     89       0
# 76   apparao   56     99       0
# 91    kamala   45     89       0
# 92   apparao   56     99       0
# 103   kamala   45     89       0
# 104  apparao   56     99       0
# 115   kamala   45     89       0
# 116  apparao   56     99       0
# 127   kamala   45     89       0
# 128  apparao   56     99       0
# 139   kamala   45     89       0
# 140  apparao   56     99       0
# 151   kamala   45     89       0
# 152  apparao   56     99       0
# 163   kamala   45     89       0
# ...

# %%
df["Name"]
# Out:
# 3       kamala
# 4      apparao
# 15      kamala
# 16     apparao
# 27      kamala
# 28     apparao
# 39      kamala
# 40     apparao
# 51      kamala
# 52     apparao
# 63      kamala
# 64     apparao
# 75      kamala
# 76     apparao
# 91      kamala
# 92     apparao
# 103     kamala
# 104    apparao
# 115     kamala
# 116    apparao
# 127     kamala
# 128    apparao
# 139     kamala
# 140    apparao
# 151     kamala
# 152    apparao
# 163     kamala
# 164    apparao
# 177     kamala
# 178    apparao
# Name: Name, dtype: object

# %%
import pandas as pd
a=pd.read_csv("data.csv")
new=pd.ExcelWriter("data.xlsx")
a.to_excel(new,index=False)
new.save()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 3>()
#       1 import pandas as pd
#       2 a=pd.read_csv("data.csv")
# ----> 3 new=pd.ExcelWriter("data.xlsx")
#       4 a.to_excel(new,index=False)
#       5 new.save()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\excel\_openpyxl.py:49, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      36 def __init__(
#      37     self,
#      38     path,
#    (...)
#      47 ):
#      48     # Use the openpyxl module as the Excel writer.
# ---> 49     from openpyxl.workbook import Workbook
#      51     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#      53     super().__init__(
#      54         path,
#      55         mode=mode,
#    (...)
# ...

# %%
import pandas as pd
a=pd.read_csv("data.csv")
a.to_excel("vandana.xlsx",sheet_name="s1",index="False")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [4], in <cell line: 3>()
#       1 import pandas as pd
#       2 a=pd.read_csv("data.csv")
# ----> 3 a.to_excel("vandana.xlsx",sheet_name="s1",index="False")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:2345, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2332 from pandas.io.formats.excel import ExcelFormatter
#    2334 formatter = ExcelFormatter(
#    2335     df,
#    2336     na_rep=na_rep,
#    (...)
#    2343     inf_rep=inf_rep,
#    2344 )
# -> 2345 formatter.write(
#    2346     excel_writer,
#    2347     sheet_name=sheet_name,
#    2348     startrow=startrow,
#    2349     startcol=startcol,
# ...
